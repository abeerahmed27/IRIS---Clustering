# %% [raw]
# Abeer Ahmed
#
# TASK - 2
#
# GRIP - The Sparks Foundation
#
#
# From the given ‘Iris’ dataset,we will predict the optimum number of clusters using K-means clustering and
# represent it visually.

# %% [markdown]
# # Importing the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Importing the dataset

# %%
dataset = pd.read_csv(r"C:\Users\Admin\Desktop\Internship\Iris.csv") #imported the data from "IRIS"
dataset.head(10)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
# 8   9            4.4           2.9            1.4           0.2  Iris-setosa
# 9  10            4.9           3.1            1.5           0.1  Iris-setosa

# %% [markdown]
# # Checking the data for any missing data

# %%
dataset.isnull().sum() #isnull() detects any missing value and it returns the answer in true for missing value and false for non-missing value
#sum() displays all the sum of non-missing values
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [raw]
# As you can see the sum is zero which means there is no missing data. we are all set to go!

# %%
x = dataset.iloc[: , :-1].values

# %%
print(x)
# Out:
# [[1.00e+00 5.10e+00 3.50e+00 1.40e+00 2.00e-01]
#  [2.00e+00 4.90e+00 3.00e+00 1.40e+00 2.00e-01]
#  [3.00e+00 4.70e+00 3.20e+00 1.30e+00 2.00e-01]
#  [4.00e+00 4.60e+00 3.10e+00 1.50e+00 2.00e-01]
#  [5.00e+00 5.00e+00 3.60e+00 1.40e+00 2.00e-01]
#  [6.00e+00 5.40e+00 3.90e+00 1.70e+00 4.00e-01]
#  [7.00e+00 4.60e+00 3.40e+00 1.40e+00 3.00e-01]
#  [8.00e+00 5.00e+00 3.40e+00 1.50e+00 2.00e-01]
#  [9.00e+00 4.40e+00 2.90e+00 1.40e+00 2.00e-01]
#  [1.00e+01 4.90e+00 3.10e+00 1.50e+00 1.00e-01]
#  [1.10e+01 5.40e+00 3.70e+00 1.50e+00 2.00e-01]
#  [1.20e+01 4.80e+00 3.40e+00 1.60e+00 2.00e-01]
#  [1.30e+01 4.80e+00 3.00e+00 1.40e+00 1.00e-01]
#  [1.40e+01 4.30e+00 3.00e+00 1.10e+00 1.00e-01]
#  [1.50e+01 5.80e+00 4.00e+00 1.20e+00 2.00e-01]
#  [1.60e+01 5.70e+00 4.40e+00 1.50e+00 4.00e-01]
#  [1.70e+01 5.40e+00 3.90e+00 1.30e+00 4.00e-01]
#  [1.80e+01 5.10e+00 3.50e+00 1.40e+00 3.00e-01]
#  [1.90e+01 5.70e+00 3.80e+00 1.70e+00 3.00e-01]
#  [2.00e+01 5.10e+00 3.80e+00 1.50e+00 3.00e-01]
# ...

# %% [markdown]
# # Feature scaling

# %%
from sklearn.preprocessing import MinMaxScaler #used scikit-learn's built in MinMaxScaler() method.
mms = MinMaxScaler()
mms.fit(x)
data_transformed = mms.transform(x)
data_transformed
# Out:
# array([[0.        , 0.22222222, 0.625     , 0.06779661, 0.04166667],
#        [0.00671141, 0.16666667, 0.41666667, 0.06779661, 0.04166667],
#        [0.01342282, 0.11111111, 0.5       , 0.05084746, 0.04166667],
#        [0.02013423, 0.08333333, 0.45833333, 0.08474576, 0.04166667],
#        [0.02684564, 0.19444444, 0.66666667, 0.06779661, 0.04166667],
#        [0.03355705, 0.30555556, 0.79166667, 0.11864407, 0.125     ],
#        [0.04026846, 0.08333333, 0.58333333, 0.06779661, 0.08333333],
#        [0.04697987, 0.19444444, 0.58333333, 0.08474576, 0.04166667],
#        [0.05369128, 0.02777778, 0.375     , 0.06779661, 0.04166667],
#        [0.06040268, 0.16666667, 0.45833333, 0.08474576, 0.        ],
#        [0.06711409, 0.30555556, 0.70833333, 0.08474576, 0.04166667],
#        [0.0738255 , 0.13888889, 0.58333333, 0.10169492, 0.04166667],
#        [0.08053691, 0.13888889, 0.41666667, 0.06779661, 0.        ],
#        [0.08724832, 0.        , 0.41666667, 0.01694915, 0.        ],
# ...

# %%
print(x)
# Out:
# [[1.00e+00 5.10e+00 3.50e+00 1.40e+00 2.00e-01]
#  [2.00e+00 4.90e+00 3.00e+00 1.40e+00 2.00e-01]
#  [3.00e+00 4.70e+00 3.20e+00 1.30e+00 2.00e-01]
#  [4.00e+00 4.60e+00 3.10e+00 1.50e+00 2.00e-01]
#  [5.00e+00 5.00e+00 3.60e+00 1.40e+00 2.00e-01]
#  [6.00e+00 5.40e+00 3.90e+00 1.70e+00 4.00e-01]
#  [7.00e+00 4.60e+00 3.40e+00 1.40e+00 3.00e-01]
#  [8.00e+00 5.00e+00 3.40e+00 1.50e+00 2.00e-01]
#  [9.00e+00 4.40e+00 2.90e+00 1.40e+00 2.00e-01]
#  [1.00e+01 4.90e+00 3.10e+00 1.50e+00 1.00e-01]
#  [1.10e+01 5.40e+00 3.70e+00 1.50e+00 2.00e-01]
#  [1.20e+01 4.80e+00 3.40e+00 1.60e+00 2.00e-01]
#  [1.30e+01 4.80e+00 3.00e+00 1.40e+00 1.00e-01]
#  [1.40e+01 4.30e+00 3.00e+00 1.10e+00 1.00e-01]
#  [1.50e+01 5.80e+00 4.00e+00 1.20e+00 2.00e-01]
#  [1.60e+01 5.70e+00 4.40e+00 1.50e+00 4.00e-01]
#  [1.70e+01 5.40e+00 3.90e+00 1.30e+00 4.00e-01]
#  [1.80e+01 5.10e+00 3.50e+00 1.40e+00 3.00e-01]
#  [1.90e+01 5.70e+00 3.80e+00 1.70e+00 3.00e-01]
#  [2.00e+01 5.10e+00 3.80e+00 1.50e+00 3.00e-01]
# ...

# %% [markdown]
# # K-Means

# %%
from sklearn.cluster import KMeans

# %%
Sum_of_squared_distances = []
K = range(1,15)
for k in K:
    km = KMeans(n_clusters=k)
    km = km.fit(data_transformed)
    Sum_of_squared_distances.append(km.inertia_)

# %% [raw]
# For each k value, we will initialise k-means and use the inertia attribute to identify the sum of squared distances of samples to the nearest cluster centre.

# %% [markdown]
# # Visualizing the result of k-means

# %%
plt.plot(K, Sum_of_squared_distances, '*-')
plt.xlabel('k')
plt.ylabel('Sum_of_squared_distances')
plt.title('Elbow Method For Optimal k')
plt.show()

# %% [raw]
# Looking at the above elbow curve is at k = 3  indicating the optimal k for this dataset is 3

# %%
km = KMeans(n_clusters = 3, init = 'k-means++',max_iter = 50, random_state = 0)
y_km = km.fit_predict(x)

# %% [markdown]
# # Visualizing the clusters

# %%
# Visualising the clusters - On the first two columns
plt.scatter(x[y_km == 0, 0], x[y_km == 0, 1], 
            s = 100, c = 'red', label = 'Iris-setosa')
plt.scatter(x[y_km == 1, 0], x[y_km == 1, 1], 
            s = 100, c = 'blue', label = 'Iris-versicolour')
plt.scatter(x[y_km == 2, 0], x[y_km == 2, 1],
            s = 100, c = 'green', label = 'Iris-virginica')

# Plotting the centroids of the clusters
plt.scatter(km.cluster_centers_[:, 0], km.cluster_centers_[:,1], 
            s = 100, c = 'yellow', label = 'Centroids' )

plt.legend()

# %% [raw]
# With the help of K-mean clustering found the best 3 clusters from the dataset .
# Used Elbow curve techiniques to get the optimal clusters
